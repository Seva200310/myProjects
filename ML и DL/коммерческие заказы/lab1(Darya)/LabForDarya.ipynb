# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, f1_score, accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
data_train=pd.read_csv("data/train.csv")
data_test=pd.read_csv("data/test.csv")
data_sample=pd.read_csv("data/sample.csv")

# %%
data_train["Liver_disease"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 388    1
# 389    2
# 390    1
# 391    1
# 392    1
# Name: Liver_disease, Length: 393, dtype: int64

# %%
data_sample["Liver_disease"].value_counts()
# Out:
# 1    165
# 2     25
# Name: Liver_disease, dtype: int64

# %%
data_train
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     72    Male              3.9               2.0                   195
# 4     26  Female              0.9               0.2                   154
# ..   ...     ...              ...               ...                   ...
# 388   32    Male             12.7               8.4                   190
# 389   60    Male              0.5               0.1                   500
# 390   40    Male              0.6               0.1                    98
# 391   52    Male              0.8               0.2                   245
# 392   31    Male              1.3               0.5                   184
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          27                          59             7.3
# 4                          16                          12             7.0
# ..                        ...                         ...             ...
# 388                        28                          47             5.4
# 389                        20                          34             5.9
# 390                        35                          31             6.0
# 391                        48                          49             6.4
# 392                        29                          32             6.8
#
#      Albumin  Albumin_and_Globulin_Ratio  Liver_disease   Id
# 0        3.3                        0.90              1    0
# 1        3.2                        0.74              1    1
# 2        3.3                        0.89              1    2
# 3        2.4                        0.40              1    3
# 4        3.5                        1.00              1    4
# ..       ...                         ...            ...  ...
# 388      2.6                        0.90              1  388
# 389      1.6                        0.37              2  389
# 390      3.2                        1.10              1  390
# 391      3.2                        1.00              1  391
# 392      3.4                        1.00              1  392
#
# [393 rows x 12 columns]

# %%
def prepare_data(data,scaler=None,mode='train'):
    #убираем лишние
    data=data.dropna()
    data=data.drop(["Id"],axis=1)
    data=pd.get_dummies(data,columns=['Gender'])
    #разбиение на х и у 
    X=data.values
    if mode=='train':
        y=data["Liver_disease"].values
        X=data.drop(["Liver_disease"],axis=1).values
    #нормализация
    if scaler==None:
        scaler = MinMaxScaler()
        scaler.fit(X)
    data=scaler.transform(X)
    #биас
    X = np.hstack([np.ones(X.shape[0])[:, np.newaxis], X])
    
    
    
    
    #разбиение на вборки
    if mode=='train':
        X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=1)
        return X_train, X_valid, y_train, y_valid,scaler,X,y
    return X
def print_logisitc_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    print(f'acc = {acc:.2f} F1-score = {f1:.2f}')

# %%
X_train, X_valid, y_train, y_valid,scaler,X,y=prepare_data(data_train,scaler=None)

# %%
clf = RandomForestClassifier(max_depth=5,n_estimators=70)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_valid)

# %%
clf = LogisticRegression(random_state=0).fit(X_train,y_train)
y_pred=clf.predict(X_valid)
# Out:
# C:\Users\sevas\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print_logisitc_metrics(y_valid, y_pred)
# Out:
# acc = 0.68 F1-score = 0.79

# %% [markdown]
# Теперь переобучим модель на всей доступной тренировочной выборке

# %%
clf = RandomForestClassifier(max_depth=5,n_estimators=70)
clf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=70)

# %% [markdown]
# подготовим тестовый датасет

# %%
X=prepare_data(data_test,scaler=scaler,mode='test')

# %%
prediction=clf.predict(X)

# %%
data_sample
# Out:
#       Id  Liver_disease
# 0    393              1
# 1    394              1
# 2    395              1
# 3    396              1
# 4    397              1
# ..   ...            ...
# 185  578              1
# 186  579              1
# 187  580              1
# 188  581              1
# 189  582              1
#
# [190 rows x 2 columns]

# %%
data_test
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     58    Male              1.0               0.4                   182
# 1     46    Male              1.8               0.7                   208
# 2     29  Female              0.9               0.3                   202
# 3     38    Male              1.8               0.8                   342
# 4     63    Male              0.9               0.2                   194
# ..   ...     ...              ...               ...                   ...
# 185   16    Male              2.6               1.2                   236
# 186   90    Male              1.1               0.3                   215
# 187   32    Male             15.6               9.5                   134
# 188   32    Male             12.1               6.0                   515
# 189   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          14                          20             6.8
# 1                          19                          14             7.6
# 2                          14                          11             6.7
# 3                         168                         441             7.6
# 4                          52                          45             6.0
# ..                        ...                         ...             ...
# 185                       131                          90             5.4
# 186                        46                         134             6.9
# 187                        54                         125             5.6
# 188                        48                          92             6.6
# 189                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio   Id
# 0        3.4                        1.00  393
# 1        4.4                        1.30  394
# 2        3.6                        1.10  395
# 3        4.4                        1.30  396
# 4        3.9                        1.85  397
# ..       ...                         ...  ...
# 185      2.6                        0.90  578
# 186      3.0                        0.70  579
# 187      4.0                        2.50  580
# 188      2.4                        0.50  581
# 189      4.4                        1.50  582
#
# [190 rows x 11 columns]

# %%
isBug=pd.Series(y_pred)

# %%
isBug.value_counts()
# Out:
# 1    66
# 2    12
# dtype: int64

# %%
data_sample["Liver_disease"]=prediction

# %%
data_sample["Liver_disease"].value_counts()
# Out:
# 1    176
# 2     14
# Name: Liver_disease, dtype: int64

# %%
submit=data_sample

# %%
submit.to_csv (r'submit.csv', index= False )

# %%
pd.read_csv("submit.csv")["Liver_disease"].value_counts()
# Out:
# 1    176
# 2     14
# Name: Liver_disease, dtype: int64

# %%
pd.read_csv("submit.csv")
# Out:
#       Id  Liver_disease
# 0    393              1
# 1    394              1
# 2    395              2
# 3    396              1
# 4    397              1
# ..   ...            ...
# 185  578              1
# 186  579              1
# 187  580              1
# 188  581              1
# 189  582              1
#
# [190 rows x 2 columns]

# %%
pd.read_csv("data/sample.csv")
# Out:
#       Id  Liver_disease
# 0    393              1
# 1    394              1
# 2    395              1
# 3    396              1
# 4    397              1
# ..   ...            ...
# 185  578              1
# 186  579              1
# 187  580              1
# 188  581              1
# 189  582              1
#
# [190 rows x 2 columns]
